# %%
from eva_cttv_pipeline.clinvar_xml_utils import *

import os
import sys
from urllib import request
import xml.etree.ElementTree as ElementTree

import hgvs
import numpy as np
import pandas as pd

# %%
sys.path.append('../')
from filter_clinvar_xml import filter_xml

# %%
pd.set_option('display.max_colwidth', None)

# %%
PROJECT_ROOT = '/home/april/projects/opentargets'
clinvar_path = os.path.join(PROJECT_ROOT, 'ClinVarFullRelease_00-latest.xml.gz')

# %%
# Only run this cell if you want to refresh clinvar data

# clinvar_url = 'https://ftp.ncbi.nlm.nih.gov/pub/clinvar/xml/ClinVarFullRelease_00-latest.xml.gz'
# request.urlretrieve(clinvar_url, clinvar_path)
# request.urlcleanup()

# %% [markdown]
# ## ClinVar documentation
#
# Submission guidelines can be found [here](https://www.ncbi.nlm.nih.gov/clinvar/docs/submit/#required), in particular note the requirement:
#
# > a valid description of the variant, one of:
# >    * an HGVS expression
# >    * chromosome coordinates and change
# >    * cytogenetic description
#
# Don't know what cytogenetic description is?  But I guess this means the submitter produces the HGVS identifier.
#
# Also found the [xsd](https://ftp.ncbi.nlm.nih.gov/pub/clinvar/clinvar_submission.xsd) for ClinVar XML submissions, which includes all possible measure types (complete with totally inconsistent capitalisation):
#
# ```xml
# <xs:simpleType name="Measuretype">
#     <xs:restriction base="xs:string">
#         <xs:enumeration value="Gene"/>
#         <xs:enumeration value="Variation"/>
#         <xs:enumeration value="Insertion"/>
#         <xs:enumeration value="Mobile element insertion"/>
#         <xs:enumeration value="Novel sequence insertion"/>
#         <xs:enumeration value="Microsatellite"/>
#         <xs:enumeration value="Deletion"/>
#         <xs:enumeration value="single nucleotide variant"/>
#         <xs:enumeration value="Multiple nucleotide variation"/>
#         <xs:enumeration value="Indel"/>
#         <xs:enumeration value="Duplication"/>
#         <xs:enumeration value="Tandem duplication"/>
#         <xs:enumeration value="copy number loss"/>
#         <xs:enumeration value="copy number gain"/>
#         <xs:enumeration value="protein only"/>
#         <xs:enumeration value="Inversion"/>
#         <xs:enumeration value="Translocation"/>
#         <xs:enumeration value="Interchromosomal breakpoint"/>
#         <xs:enumeration value="Intrachromosomal breakpoint"/>
#         <xs:enumeration value="Complex"/>
#     </xs:restriction>
# </xs:simpleType>
# ```
# Compare measure types we've actually found in the data, [here](https://github.com/EBIvariation/eva-opentargets/tree/master/clinvar-variant-types).

# %% [markdown]
# ## Filter
#
# Filter full dataset to get just a manageable (hopefully representative) sample of records with measures representing complex events

# %%
complex_xml = os.path.join(PROJECT_ROOT, 'complex-events.xml.gz')

# %%
# get just "complex events"
# Q: what's complex? -- complex == no full coordinates
def complex_measures(x):
    if x.measure:
        return (
            # smattering of all non SNV variants
            (x.measure.variant_type.lower() not in {'single nucleotide variant'} and np.random.random() < 0.01)
            # be sure to get the rare ones
            or (x.measure.variant_type.lower() in {'tandem duplication', 'fusion', 'complex', 'translocation', 'inversion'})
        )
    return False

filter_xml(
    input_xml=clinvar_path,
    output_xml=complex_xml,
    filter_fct=complex_measures,
)
# Out:
# Records written: 3040

# %%
dataset = ClinVarDataset(complex_xml)

# %% [markdown]
# ## Dataframe
#
# Load measures into a dataframe where columns are the properties.

# %%
def get_measures(dataset):
    for r in dataset:
        if r.measure:
            yield r.measure

# %%
for m in get_measures(dataset):
    break
    
dir(m)
# Out:
# ['MS_DELETION',
#  'MS_NO_COMPLETE_COORDS',
#  'MS_REPEAT_EXPANSION',
#  'MS_SHORT_EXPANSION',
#  'REPEAT_EXPANSION_THRESHOLD',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_hgvs_elems',
#  'all_names',
#  'chr',
#  'clinvar_record',
#  'explicit_insertion_length',
#  'has_complete_coordinates',
#  'hgnc_ids',
#  'hgvs',
#  'is_repeat_expansion_variant',
#  'measure_xml',
#  'microsatellite_category',
#  'nsv_id',
#  'preferred_gene_symbols',
#  'preferred_name',
#  'preferred_or_other_name',
#  'pubmed_refs',
#  'rs_id',
#  'sequence_location_helper',
#  'toplevel_refseq_hgvs',
#  'variant_type',
#  'vcf_alt',
#  'vcf_full_coords',
#  'vcf_pos',
#  'vcf_ref']

# %%
# just all the properties
props = [
 'all_names',
 'clinvar_record',
#  'explicit_insertion_length',
#  'has_complete_coordinates',
 'hgnc_ids',
 'hgvs',
 'is_repeat_expansion_variant',
#  'measure_xml',
 'microsatellite_category',
 'nsv_id',
 'preferred_gene_symbols',
#  'preferred_name',
 'preferred_or_other_name',
#  'pubmed_refs',
 'rs_id',
#  'sequence_location_helper',
#  'toplevel_refseq_hgvs',
 'variant_type',
 'chr',
 'vcf_alt',
#  'vcf_full_coords',
 'vcf_pos',
 'vcf_ref'
]

# %%
# replaces empty list with None
measures = [[getattr(v, p) if getattr(v, p) != [] else None for p in props] for v in get_measures(dataset)]

# %%
df = pd.DataFrame(measures, columns=props)

# %%
df.count()
# Out:
# all_names                      2999
# clinvar_record                 3040
# hgnc_ids                       2610
# hgvs                           2392
# is_repeat_expansion_variant    3040
# microsatellite_category         208
# nsv_id                          272
# preferred_gene_symbols         2613
# preferred_or_other_name        2999
# rs_id                           996
# variant_type                   3040
# chr                            2033
# vcf_alt                        1830
# vcf_pos                        1830
# vcf_ref                        1830
# dtype: int64

# %%
set(df['variant_type'])
# Out:
# {'Complex',
#  'Deletion',
#  'Duplication',
#  'Indel',
#  'Insertion',
#  'Inversion',
#  'Microsatellite',
#  'Tandem duplication',
#  'Translocation',
#  'Variation',
#  'copy number gain',
#  'copy number loss',
#  'fusion',
#  'protein only'}

# %%
df[pd.notna(df['preferred_or_other_name'].str.contains('dup'))]
# Out:
#                                                                                all_names  \
# 0                                                               [46;XY;inv(4)(q12q13.2)]
# 1                                                            [46;XX;t(1;5)(p32.1;q31.3)]
# 2                                                             [46;XY;t(1;15)(p22.3;q15)]
# 3                                                         [46;XX;t(2;11)(p13.1;p15.5)dn]
# 4                                                              [46;XY;t(5;8)(q15;q22.1)]
# ...                                                                                  ...
# 3035  [K616del, MLH1, 3-BP DEL, LYS618DEL, NM_000249.4(MLH1):c.1846AAG[2] (p.Lys618del)]
# 3036                                                [NM_001098.3(ACO2):c.433-2_433-1inv]
# 3037                                    [NM_000059.3(BRCA2):c.5238dupT (p.Asn1747Terfs)]
# 3038                                             [NM_000059.4(BRCA2):c.26del (p.Pro9fs)]
# 3039                            [NM_000179.2 (MSH6):c.3984_3987dupGTCA (p.Leu1330Valfs)]
#
#                                         clinvar_record     hgnc_ids  \
# 0     ClinVarRecord object with accession RCV000258541         None
# 1     ClinVarRecord object with accession RCV000258575         None
# 2     ClinVarRecord object with accession RCV000258594         None
# 3     ClinVarRecord object with accession RCV000258610         None
# 4     ClinVarRecord object with accession RCV000258613         None
# ...                                                ...          ...
# 3035  ClinVarRecord object with accession RCV001249999  [HGNC:7127]
# 3036  ClinVarRecord object with accession RCV001255994   [HGNC:118]
# 3037  ClinVarRecord object with accession RCV001262734  [HGNC:1101]
# 3038  ClinVarRecord object with accession RCV001353718  [HGNC:1101]
# 3039  ClinVarRecord object with accession RCV001357388  [HGNC:7329]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          hgvs  \
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        None
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        None
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        None
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        None
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        None
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       ...
# 3035  [NM_000249.3:c.1845_1847delGAA, NM_000249.4:c.1852_1854del, NM_000249.3:c.1852_1854delAAG, NM_001167618.3:c.1123AAG[2], NM_001167619.3:c.1123AAG[2], NM_001258273.2:c.1123AAG[2], NM_001258274.3:c.1123AAG[2], NM_001354615.2:c.1123AAG[2], NM_001354616.2:c.1123AAG[2], NM_001354617.2:c.1123AAG[2], NM_001354618.2:c.1123AAG[2], NM_001354619.2:c.1123AAG[2], NM_001167617.3:c.1552AAG[2], NM_001354620.2:c.1552AAG[2], NM_001354630.2:c.1732-885GAA[2], NM_001354629.2:c.1747AAG[2], NM_000249.4:c.1846AAG[2], NM_001258271.2:c.1846AAG[2], NM_001354628.2:c.1846AAG[2], NM_001354624.2:c.772AAG[2], NM_001354625.2:c.772AAG[2], NM_001354626.2:c.772AAG[2], NM_001354627.2:c.772AAG[2], NM_001354621.2:c.823AAG[2], NM_001354622.2:c.823AAG[2], NM_001354623.2:c.823AAG[2], LRG_216:g.59284AAG[2], NG_007109.2:g.59284AAG[2], NC_000003.12:g.37047633AAG[2], NC_000003.11:g.37089123_37089125del, NC_000003.11:g.37089123_37089125del, NC_000003.11:g.37089130_37089132del, NC_000003.11:g.37089130_37089132delAAG, NC_000003.11:g.37089124AAG[2], None, p.K616del, p.K618del, NP_001341553.1:p.Lys260del, NP_001341554.1:p.Lys260del, NP_001341555.1:p.Lys260del, NP_001341556.1:p.Lys260del, NP_001341550.1:p.Lys277del, NP_001341551.1:p.Lys277del, NP_001341552.1:p.Lys277del, NP_001161090.1:p.Lys377del, NP_001161091.1:p.Lys377del, NP_001245202.1:p.Lys377del, NP_001245203.1:p.Lys377del, NP_001341544.1:p.Lys377del, NP_001341545.1:p.Lys377del, NP_001341546.1:p.Lys377del, NP_001341547.1:p.Lys377del, NP_001341548.1:p.Lys377del, NP_001161089.1:p.Lys520del, NP_001341549.1:p.Lys520del, NP_001341558.1:p.Lys585del, NP_000240.1:p.Lys618del, NP_001245200.1:p.Lys618del, NP_001341557.1:p.Lys618del]
# 3036                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [NM_001098.3:c.433-2_433-1inv, NG_032143.1:g.47750_47751delinsCT, NG_032143.1:g.47750_47751delinsCT, NG_032143.1:g.47750_47751inv, NC_000022.11:g.41511874_41511875inv, NC_000022.10:g.41907878_41907879inv, c.433-2_443-1delinsCT, NM_001098.2:c.433-2_433-1delinsCT]
# 3037                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [NM_000059.3:c.5238dupT, NM_000059.4:c.5238dup, LRG_293:g.29114dup, NG_012772.3:g.29114dup, NC_000013.11:g.32339593dup, NC_000013.10:g.32913729_32913730insT, NC_000013.10:g.32913730dup, U43746.1:n.5466_5467insT, None, p.Asn1747*, p.N1747*, p.N1747X, NP_000050.3:p.Asn1747Ter]
# 3038                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [NM_000059.3:c.26delC, NM_000059.4:c.26del, LRG_293:g.6007del, NG_017006.2:g.3879del, NG_017006.1:g.470del, NG_012772.3:g.6007del, NC_000013.11:g.32316486del, NC_000013.10:g.32890622del, NC_000013.10:g.32890623delC, NC_000013.10:g.32890623del, U43746.1:n.254delC, None, p.P9QFS*16, p.Pro9Glnfs*16, NP_000050.3:p.Pro9fs]
# 3039                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [NM_000179.2:c.3984_3987dupGTCA, LRG_219t1:c.3984_3987dup, NM_001281493.1:c.3078_3081dup, NM_001281494.1:c.3078_3081dup, NM_001281492.1:c.3594_3597dup, NM_000179.3:c.3984_3987dup, LRG_219:g.28488_28491dup, NG_008397.1:g.104042_104045dup, NG_007111.1:g.28488_28491dup, NC_000002.12:g.47806634_47806637dup, NC_000002.11:g.48033769_48033770insTCAG, NC_000002.11:g.48033769_48033770insTCAG, NC_000002.11:g.48033776_48033777insGTCA, NC_000002.11:g.48033773_48033776dup, p.L1330AfsX12, p.L1330Vfs*12, p.Leu1330Valfs*12, LRG_219p1:p.Leu1330fs, NP_001268422.1:p.Leu1028fs, NP_001268423.1:p.Leu1028fs, NP_001268421.1:p.Leu1200fs]
#
#       is_repeat_expansion_variant microsatellite_category nsv_id  \
# 0                           False                    None   None
# 1                           False                    None   None
# 2                           False                    None   None
# 3                           False                    None   None
# 4                           False                    None   None
# ...                           ...                     ...    ...
# 3035                        False                deletion   None
# 3036                        False                    None   None
# 3037                        False                    None   None
# 3038                        False                    None   None
# 3039                        False                    None   None
#
#      preferred_gene_symbols  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ...                     ...
# 3035                 [MLH1]
# 3036                 [ACO2]
# 3037                [BRCA2]
# 3038                [BRCA2]
# 3039                 [MSH6]
#
#                                      preferred_or_other_name        rs_id  \
# 0                                     46;XY;inv(4)(q12q13.2)         None
# 1                                  46;XX;t(1;5)(p32.1;q31.3)         None
# 2                                   46;XY;t(1;15)(p22.3;q15)         None
# 3                               46;XX;t(2;11)(p13.1;p15.5)dn         None
# 4                                    46;XY;t(5;8)(q15;q22.1)         None
# ...                                                      ...          ...
# 3035            NM_000249.4(MLH1):c.1846AAG[2] (p.Lys618del)   rs63751247
# 3036                      NM_001098.3(ACO2):c.433-2_433-1inv         None
# 3037          NM_000059.3(BRCA2):c.5238dupT (p.Asn1747Terfs)   rs80359499
# 3038                   NM_000059.4(BRCA2):c.26del (p.Pro9fs)   rs80359343
# 3039  NM_000179.2 (MSH6):c.3984_3987dupGTCA (p.Leu1330Valfs)  rs267608121
#
#         variant_type   chr vcf_alt   vcf_pos vcf_ref
# 0          Inversion  None    None      None    None
# 1      Translocation  None    None      None    None
# 2      Translocation  None    None      None    None
# 3      Translocation  None    None      None    None
# 4      Translocation  None    None      None    None
# ...              ...   ...     ...       ...     ...
# 3035  Microsatellite     3       T  37047631    TGAA
# 3036       Inversion    22      CT  41511874      AG
# 3037     Duplication    13      CT  32339592       C
# 3038        Deletion    13       G  32316484      GC
# 3039     Duplication     2   ATCAG  47806630       A
#
# [2999 rows x 15 columns]

# %%
df[df.variant_type == 'Translocation']
# Out:
#                            all_names  \
# 1        [46;XX;t(1;5)(p32.1;q31.3)]
# 2         [46;XY;t(1;15)(p22.3;q15)]
# 3     [46;XX;t(2;11)(p13.1;p15.5)dn]
# 4          [46;XY;t(5;8)(q15;q22.1)]
# 5         [46;XY;t(5;15)(q13.1;q13)]
# ...                              ...
# 2732           [t(6;9)(q23.3;p22.3)]
# 2766          [t(X;8)(p22.13;q12.1)]
# 2767         [t(8;9)(q24.22;q34.13)]
# 2772          [t(5;22)(q31.2;q12.1)]
# 2820                            None
#
#                                         clinvar_record  \
# 1     ClinVarRecord object with accession RCV000258575
# 2     ClinVarRecord object with accession RCV000258594
# 3     ClinVarRecord object with accession RCV000258610
# 4     ClinVarRecord object with accession RCV000258613
# 5     ClinVarRecord object with accession RCV000258628
# ...                                                ...
# 2732  ClinVarRecord object with accession RCV000585780
# 2766  ClinVarRecord object with accession RCV000767228
# 2767  ClinVarRecord object with accession RCV000767229
# 2772  ClinVarRecord object with accession RCV000785874
# 2820  ClinVarRecord object with accession RCV001256208
#
#                       hgnc_ids  hgvs  is_repeat_expansion_variant  \
# 1                         None  None                        False
# 2                         None  None                        False
# 3                         None  None                        False
# 4                         None  None                        False
# 5                         None  None                        False
# ...                        ...   ...                          ...
# 2732    [HGNC:7545, HGNC:7785]  None                        False
# 2766  [HGNC:28509, HGNC:20626]  None                        False
# 2767  [HGNC:12362, HGNC:26572]  None                        False
# 2772                      None  None                        False
# 2820   [HGNC:13487, HGNC:3689]  None                        False
#
#      microsatellite_category nsv_id preferred_gene_symbols  \
# 1                       None   None                   None
# 2                       None   None                   None
# 3                       None   None                   None
# 4                       None   None                   None
# 5                       None   None                   None
# ...                      ...    ...                    ...
# 2732                    None   None            [MYB, NFIB]
# 2766                    None   None          [BEND2, CHD7]
# 2767                    None   None         [TSC1, TMEM71]
# 2772                    None   None                   None
# 2820                    None   None         [VPS35, FGFR2]
#
#            preferred_or_other_name rs_id   variant_type   chr vcf_alt vcf_pos  \
# 1        46;XX;t(1;5)(p32.1;q31.3)  None  Translocation  None    None    None
# 2         46;XY;t(1;15)(p22.3;q15)  None  Translocation  None    None    None
# 3     46;XX;t(2;11)(p13.1;p15.5)dn  None  Translocation  None    None    None
# 4          46;XY;t(5;8)(q15;q22.1)  None  Translocation  None    None    None
# 5         46;XY;t(5;15)(q13.1;q13)  None  Translocation  None    None    None
# ...                            ...   ...            ...   ...     ...     ...
# 2732           t(6;9)(q23.3;p22.3)  None  Translocation  None    None    None
# 2766          t(X;8)(p22.13;q12.1)  None  Translocation  None    None    None
# 2767         t(8;9)(q24.22;q34.13)  None  Translocation  None    None    None
# 2772          t(5;22)(q31.2;q12.1)  None  Translocation  None    None    None
# 2820                          None  None  Translocation  None    None    None
#
#      vcf_ref
# 1       None
# 2       None
# 3       None
# 4       None
# 5       None
# ...      ...
# 2732    None
# 2766    None
# 2767    None
# 2772    None
# 2820    None
#
# [259 rows x 15 columns]

# %% [markdown]
# ## XML
#
# Probably not all elements from the raw xml are captured in the object, can we get find anything there?

# %%
def get_measure_xml_for_rcv(dataset, rcv):
    for r in dataset:
        if r.accession == rcv:
            return r.measure.measure_xml


# pretty print xml
def pprint(x):
    print(ElementTree.tostring(x, encoding='unicode'))


def print_measure_xml_for_rcv(dataset, rcv):
    x = get_measure_xml_for_rcv(dataset, rcv)
    pprint(x)

# %%
xml = get_measure_xml_for_rcv(dataset, 'RCV001372309')

# %%
pprint(xml)
# Out:
# <Measure Type="Duplication" ID="1039262">
#         <Name>
#           <ElementValue Type="Preferred">NC_000023.10:g.(?_31514885)_(32430050_?)dup</ElementValue>
#         </Name>
#         <AttributeSet>
#           <Attribute Accession="NC_000023" Version="10" Change="g.(?_31514885)_(32430050_?)dup" Type="HGVS, genomic, top level, previous" integerValue="37">NC_000023.10:g.(?_31514885)_(32430050_?)dup</Attribute>
#         </AttributeSet>
#         <CytogeneticLocation>Xp21.1</CytogeneticLocation>
#         <SequenceLocation Assembly="GRCh37" AssemblyAccessionVersion="GCF_000001405.25" AssemblyStatus="previous" Chr="X" Accession="NC_000023.10" innerStart="31514885" innerStop="32430050" display_start="31514885" display_stop="32430050" variantLength="915166" />
#         <MeasureRelationship Type="within single gene">
#           <Name>
#             <ElementValue Type="Preferred">dystrophin</ElementValue>
#           </Name>
#           <Symbol>
#             <ElementValue Type="Preferred">DMD</ElementValue>
#           </Symbol>
#           <AttributeSet>
#             <Attribute dateValue="2019-11-20" Type="Haploinsufficiency">Sufficient evidence for dosage pathogenicity</Attribute>
#             <Citation>
#               <URL>https://www.ncbi.nlm.nih.gov/projects/dbvar/ISCA/isca_gene.cgi?sym=DMD</URL>
#             </Citation>
#           </AttributeSet>
#           <AttributeSet>
#             <Attribute dateValue="2019-11-20" Type="Triplosensitivity">No evidence available</Attribute>
#             <Citation>
#               <URL>https://www.ncbi.nlm.nih.gov/projects/dbvar/ISCA/isca_gene.cgi?sym=DMD</URL>
#             </Citation>
#           </AttributeSet>
#           <SequenceLocation Assembly="GRCh38" AssemblyAccessionVersion="GCF_000001405.38" AssemblyStatus="current" Chr="X" Accession="NC_000023.11" start="31119219" stop="33339460" display_start="31119219" display_stop="33339460" Strand="-" />
#           <SequenceLocation Assembly="GRCh37" AssemblyAccessionVersion="GCF_000001405.25" AssemblyStatus="previous" Chr="X" Accession="NC_000023.10" start="31137344" stop="33357725" display_start="31137344" display_stop="33357725" variantLength="2220382" Strand="-" />
#           <XRef ID="1756" DB="Gene" />
#           <XRef Type="MIM" ID="300377" DB="OMIM" />
#           <XRef ID="HGNC:2928" DB="HGNC" />
#         </MeasureRelationship>
#       </Measure>

# %%
hp.parse_hgvs_variant('NC_000023.10:g.(?_31514885)_(32430050_?)dup')
# Out:
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/hgvs/parser.py in rule_fxn(s)
#     129                 try:
# --> 130                     return self._grammar(s).__getattr__(rule_name)()
#     131                 except ometa.runtime.ParseError as exc:
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/parsley.py in invokeRule(*args, **kwargs)
#      97                                      [["message", "expected EOF"]], err.trail)
# ---> 98             raise err
#      99         return invokeRule
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/ometa/runtime.py in _or(self, fns)
#     597                 m = self.input
# --> 598                 ret, err = f()
#     599                 errors.append(err)
#
# /pymeta_generated_code/pymeta_grammar__Grammar.py in _G_or_208()
#     793                 self._trace('| dna_subs', (5477, 5487), self.input.position)
# --> 794                 _G_apply_209, lastError = self._apply(self.rule_dna_subst, "dna_subst", [])
#     795                 self.considerError(lastError, None)
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/ometa/runtime.py in _apply(self, rule, ruleName, args)
#     494                 memoRec = self.input.setMemo(ruleName,
# --> 495                                          [rule(), self.input])
#     496             except ParseError as e:
#
# /pymeta_generated_code/pymeta_grammar__Grammar.py in rule_dna_subst(self)
#     863             self._trace('= dn', (5651, 5655), self.input.position)
# --> 864             _G_apply_233, lastError = self._apply(self.rule_dna, "dna", [])
#     865             self.considerError(lastError, 'dna_subst')
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/ometa/runtime.py in _apply(self, rule, ruleName, args)
#     515             memoRec.detected = True
# --> 516             raise self.input.nullError()
#     517         self.input = memoRec[1]
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/ometa/runtime.py in many(self, fn, *initial)
#     553                 m = self.input
# --> 554                 v, _ = fn()
#     555                 ans.append(v)
#
# /pymeta_generated_code/pymeta_grammar__Grammar.py in _G_many_226()
#     842                     self._trace('<dn', (5576, 5579), self.input.position)
# --> 843                     _G_apply_227, lastError = self._apply(self.rule_dna, "dna", [])
#     844                     self.considerError(lastError, None)
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/ometa/runtime.py in _apply(self, rule, ruleName, args)
#     494                 memoRec = self.input.setMemo(ruleName,
# --> 495                                          [rule(), self.input])
#     496             except ParseError as e:
#
# /pymeta_generated_code/pymeta_grammar__Grammar.py in rule_dna(self)
#    2667             self._trace('= dna_iupa', (11894, 11904), self.input.position)
# -> 2668             _G_apply_809, lastError = self._apply(self.rule_dna_iupac, "dna_iupac", [])
#    2669             self.considerError(lastError, 'dna')
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/ometa/runtime.py in _apply(self, rule, ruleName, args)
#     494                 memoRec = self.input.setMemo(ruleName,
# --> 495                                          [rule(), self.input])
#     496             except ParseError as e:
#
# /pymeta_generated_code/pymeta_grammar__Grammar.py in rule_dna_iupac(self)
#    2682                 return (_G_python_813, self.currentError)
# -> 2683             _G_pred_814, lastError = self.pred(_G_pred_811)
#    2684             self.considerError(lastError, 'dna_iupac')
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/ometa/runtime.py in pred(self, expr)
#     648         if not val:
# --> 649             raise e
#     650         else:
#
# ParseError:
# NC_000023.10:g.(?_31514885)_(32430050_?)dup
#                            ^
# Parse error at line 1, column 27: expected one of '=', 'con', 'copy', 'del', 'dup', 'ins', or 'inv'. trail: [dna_iupac dna dna_ident dna_subst dna_delins dna_ins dna_del dna_dup dna_inv dna_con dna_copy dna_edit g_posedit g_variant hgvs_variant]
#
#
# During handling of the above exception, another exception occurred:
#
# HGVSParseError                            Traceback (most recent call last)
# /tmp/ipykernel_1004246/1187591864.py in <module>
# ----> 1 hp.parse_hgvs_variant('NC_000023.10:g.(?_31514885)_(32430050_?)dup')
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/hgvs/parser.py in rule_fxn(s)
#     130                     return self._grammar(s).__getattr__(rule_name)()
#     131                 except ometa.runtime.ParseError as exc:
# --> 132                     raise HGVSParseError("{s}: char {exc.position}: {reason}".format(
#     133                         s=s, exc=exc, reason=exc.formatReason()))
#     134
#
# HGVSParseError: NC_000023.10:g.(?_31514885)_(32430050_?)dup: char 27: expected one of '=', 'con', 'copy', 'del', 'dup', 'ins', or 'inv'

# %%
xml2 = get_measure_xml_for_rcv(dataset, 'RCV001255994')
pprint(xml2)
# Out:
# <Measure Type="Inversion" ID="966181">
#         <Name>
#           <ElementValue Type="Preferred">NM_001098.3(ACO2):c.433-2_433-1inv</ElementValue>
#         </Name>
#         <CanonicalSPDI>NC_000022.11:41511873:AG:CT</CanonicalSPDI>
#         <AttributeSet>
#           <Attribute Accession="NM_001098" Version="3" Change="c.433-2_433-1inv" Type="HGVS, coding, RefSeq" MANESelect="true">NM_001098.3:c.433-2_433-1inv</Attribute>
#         </AttributeSet>
#         <AttributeSet>
#           <Attribute Change="g.47750_47751delinsCT" Accession="NG_032143" Version="1" Type="HGVS, genomic">NG_032143.1:g.47750_47751delinsCT</Attribute>
#         </AttributeSet>
#         <AttributeSet>
#           <Attribute Accession="NG_032143" Version="1" Change="g.47750_47751delinsCT" Type="HGVS, genomic, RefSeqGene">NG_032143.1:g.47750_47751delinsCT</Attribute>
#         </AttributeSet>
#         <AttributeSet>
#           <Attribute Accession="NG_032143" Version="1" Change="g.47750_47751inv" Type="HGVS, genomic, RefSeqGene">NG_032143.1:g.47750_47751inv</Attribute>
#         </AttributeSet>
#         <AttributeSet>
#           <Attribute Accession="NC_000022" Version="11" Change="g.41511874_41511875inv" Type="HGVS, genomic, top level" integerValue="38">NC_000022.11:g.41511874_41511875inv</Attribute>
#         </AttributeSet>
#         <AttributeSet>
#           <Attribute Accession="NC_000022" Version="10" Change="g.41907878_41907879inv" Type="HGVS, genomic, top level, previous" integerValue="37">NC_000022.10:g.41907878_41907879inv</Attribute>
#         </AttributeSet>
#         <AttributeSet>
#           <Attribute Type="HGVS, incomplete">c.433-2_443-1delinsCT</Attribute>
#         </AttributeSet>
#         <AttributeSet>
#           <Attribute Accession="NM_001098" Version="2" Change="c.433-2_433-1delinsCT" Type="HGVS, previous">NM_001098.2:c.433-2_433-1delinsCT</Attribute>
#         </AttributeSet>
#         <AttributeSet>
#           <Attribute Type="MolecularConsequence">splice acceptor variant</Attribute>
#           <XRef ID="SO:0001574" DB="Sequence Ontology" />
#           <XRef ID="NM_001098.3:c.433-2_433-1inv" DB="RefSeq" />
#         </AttributeSet>
#         <CytogeneticLocation>22q13.2</CytogeneticLocation>
#         <SequenceLocation Assembly="GRCh38" AssemblyAccessionVersion="GCF_000001405.38" AssemblyStatus="current" Chr="22" Accession="NC_000022.11" start="41511874" stop="41511875" display_start="41511874" display_stop="41511875" variantLength="2" positionVCF="41511874" referenceAlleleVCF="AG" alternateAlleleVCF="CT" />
#         <SequenceLocation Assembly="GRCh37" AssemblyAccessionVersion="GCF_000001405.25" AssemblyStatus="previous" Chr="22" Accession="NC_000022.10" start="41907878" stop="41907879" display_start="41907878" display_stop="41907879" variantLength="2" positionVCF="41907878" referenceAlleleVCF="AG" alternateAlleleVCF="CT" />
#         <MeasureRelationship Type="within single gene">
#           <Name>
#             <ElementValue Type="Preferred">aconitase 2</ElementValue>
#           </Name>
#           <Symbol>
#             <ElementValue Type="Preferred">ACO2</ElementValue>
#           </Symbol>
#           <SequenceLocation Assembly="GRCh38" AssemblyAccessionVersion="GCF_000001405.38" AssemblyStatus="current" Chr="22" Accession="NC_000022.11" start="41468756" stop="41528979" display_start="41468756" display_stop="41528979" Strand="+" />
#           <SequenceLocation Assembly="GRCh37" AssemblyAccessionVersion="GCF_000001405.25" AssemblyStatus="previous" Chr="22" Accession="NC_000022.10" start="41865128" stop="41924992" display_start="41865128" display_stop="41924992" variantLength="59865" Strand="+" />
#           <XRef ID="50" DB="Gene" />
#           <XRef Type="MIM" ID="100850" DB="OMIM" />
#           <XRef ID="HGNC:118" DB="HGNC" />
#         </MeasureRelationship>
#         <XRef Type="Allelic variant" ID="100850.0010" DB="OMIM" />
#       </Measure>

# %%
for x in find_elements(xml, 'CytogeneticLocation'):
    pprint(x)
# Out:
# <CytogeneticLocation>1q44</CytogeneticLocation>

# %% [markdown]
# ## HGVS
#
# Trying out the [hgvs](https://github.com/biocommons/hgvs) library.

# %%
import hgvs.parser
hp = hgvs.parser.Parser()

# %%
for r in dataset:
    h = r.measure.toplevel_refseq_hgvs
    if h:
        print(h + ' :: ' + str(hp.parse_hgvs_variant(h)))
# Out:
# NC_000015.10:g.35742132_35744286del :: NC_000015.10:g.35742132_35744286del
# NC_000012.12:g.45848963del :: NC_000012.12:g.45848963del
# ---------------------------------------------------------------------------
# ParseError                                Traceback (most recent call last)
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/hgvs/parser.py in rule_fxn(s)
#     129                 try:
# --> 130                     return self._grammar(s).__getattr__(rule_name)()
#     131                 except ometa.runtime.ParseError as exc:
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/parsley.py in invokeRule(*args, **kwargs)
#      97                                      [["message", "expected EOF"]], err.trail)
# ---> 98             raise err
#      99         return invokeRule
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/ometa/runtime.py in many(self, fn, *initial)
#     553                 m = self.input
# --> 554                 v, _ = fn()
#     555                 ans.append(v)
#
# /pymeta_generated_code/pymeta_grammar__Grammar.py in _G_many_226()
#     842                     self._trace('<dn', (5576, 5579), self.input.position)
# --> 843                     _G_apply_227, lastError = self._apply(self.rule_dna, "dna", [])
#     844                     self.considerError(lastError, None)
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/ometa/runtime.py in _apply(self, rule, ruleName, args)
#     494                 memoRec = self.input.setMemo(ruleName,
# --> 495                                          [rule(), self.input])
#     496             except ParseError as e:
#
# /pymeta_generated_code/pymeta_grammar__Grammar.py in rule_dna(self)
#    2667             self._trace('= dna_iupa', (11894, 11904), self.input.position)
# -> 2668             _G_apply_809, lastError = self._apply(self.rule_dna_iupac, "dna_iupac", [])
#    2669             self.considerError(lastError, 'dna')
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/ometa/runtime.py in _apply(self, rule, ruleName, args)
#     494                 memoRec = self.input.setMemo(ruleName,
# --> 495                                          [rule(), self.input])
#     496             except ParseError as e:
#
# /pymeta_generated_code/pymeta_grammar__Grammar.py in rule_dna_iupac(self)
#    2682                 return (_G_python_813, self.currentError)
# -> 2683             _G_pred_814, lastError = self.pred(_G_pred_811)
#    2684             self.considerError(lastError, 'dna_iupac')
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/ometa/runtime.py in pred(self, expr)
#     648         if not val:
# --> 649             raise e
#     650         else:
#
# ParseError:
# NC_000003.12:g.101226227_101226228AT[26]
#                                     ^
# Parse error at line 1, column 36: expected the character '='. trail: [dna_iupac dna dna_ident dna_edit g_posedit g_variant hgvs_variant]
#
#
# During handling of the above exception, another exception occurred:
#
# HGVSParseError                            Traceback (most recent call last)
# /tmp/ipykernel_1004246/2391227387.py in <module>
#       2     h = r.measure.toplevel_refseq_hgvs
#       3     if h:
# ----> 4         print(h + ' :: ' + str(hp.parse_hgvs_variant(h)))
#
# ~/projects/eva-opentargets/env/lib/python3.8/site-packages/hgvs/parser.py in rule_fxn(s)
#     130                     return self._grammar(s).__getattr__(rule_name)()
#     131                 except ometa.runtime.ParseError as exc:
# --> 132                     raise HGVSParseError("{s}: char {exc.position}: {reason}".format(
#     133                         s=s, exc=exc, reason=exc.formatReason()))
#     134
#
# HGVSParseError: NC_000003.12:g.101226227_101226228AT[26]: char 36: expected the character '='

# %%
# from code to make variant from scratch
start = hgvs.location.BaseOffsetPosition(base=200,offset=-6,datum=hgvs.location.Datum.CDS_START)
end = hgvs.location.BaseOffsetPosition(base=22,datum=hgvs.location.Datum.CDS_END)
iv = hgvs.location.Interval(start=start,end=end)

edit = hgvs.edit.NARefAlt(ref='A',alt='T')

posedit = hgvs.posedit.PosEdit(pos=iv,edit=edit)

var = hgvs.sequencevariant.SequenceVariant(ac='NM_01234.5', type='c', posedit=posedit)

# %%
var, str(var)
# Out:
# (SequenceVariant(ac=NM_01234.5, type=c, posedit=200-6_*22A>T, gene=None),
#  'NM_01234.5:c.200-6_*22A>T')

# %% [markdown]
# ## Summary for ticket
#
# ### ClinVar documentation
#
# Submission guidelines can be found [here](https://www.ncbi.nlm.nih.gov/clinvar/docs/submit/#required), in particular note the requirement:
# > * a valid description of the variant, one of:
# >    * an HGVS expression
# >    * chromosome coordinates and change
# >    * cytogenetic description
#
# ### Notes from 4 August meeting
#
# Tentatively define "complex events" as variants without full `chr_pos_ref_alt` coordinates, as these are variants that aren't handled by the core VEP-based functional consequence pipeline.  Some of these *are* handled by the specialised repeat expansion pipeline, so we can focus on the rest.
#
# To really deal with complex events, besides identifiers we also need to get *functional consequences*, otherwise they get dropped by the pipeline.
#
# Next steps:
# 1. Collect more representative examples of complex events in ClinVar
# 1. Look at distribution of records with no functional consequences
#     * How many have HGVS-esque identifiers, sequence location with start/stop position, cytogenetic location?
#     * Of those with no full coordinates, how many can we parse? How many can the official HGVS parser parse?
#     * How are unparseable HGVS identifiers failing?  Is there some systematic way people are using HGVS-esque identifiers that aren't _technically_ HGVS-compliant but we can still parse reliably?
# 1. What does VEP require to get consequences? Biologically we should only need start/stop coordinates.
# 1. Can we report variant/phenotype associations without functional consequences, similar to ontology mappings?  Is this still valuable to OT?
#     * Can we report functional consequences with some uncertainty?  For example some HGVS identifiers encode uncertain location, e.g. [here](https://www.ncbi.nlm.nih.gov/clinvar/variation/1062574/).
#
# (1) and (2) I've started doing and will post in a subsequent comment before the next meeting.
